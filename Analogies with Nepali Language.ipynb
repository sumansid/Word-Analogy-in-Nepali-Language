# %% [markdown]
# ##  Analogies with Nepali Language

# %%
import numpy as np

# %%
## File Paths
word_2_vec = "nepali_embeddings_word2vec.txt"

# %%
def read_word_to_vecs(pretrained_file):
    with open(pretrained_file, 'r') as f:
        words = set()
        word_to_vec_map = {}
        
        for line in f:
            line = line.strip().split()
            curr_word = line[0]
            words.add(curr_word)
            word_to_vec_map[curr_word] = np.array(line[1:], dtype=np.float64)
            
    return words, word_to_vec_map

# %%
words, word_to_vec_map = read_word_to_vecs(word_2_vec)

# %%
def cosine_similarity(u,v): 
    """
    u : Word vector
    V : Word vector
    
    Returns : 
        Cosine similarity
    
    """
    # dot product of the word vectors
    dot_product = np.dot(u,v)
    # L2 norms ie. Distance
    dist_u = np.sqrt(np.sum(u**2))
    dist_v = np.sqrt(np.sum(v**2))
    cosine_similarity = dot_product/(dist_u*dist_v)
    return cosine_similarity

# %%
word_u = word_to_vec_map["ठमेल"]
word_v = word_to_vec_map["न्यूरोड"]
cosine_similarity(word_u,word_v)
# Out:
# True

# %%
def analogy_finder(word_a, word_b, word_c, word_2_vec_map, word_list):
    e_a, e_b, e_c = word_2_vec_map[word_a],word_to_vec_map[word_b],word_to_vec_map[word_c]
    words = word_list
    max_cosine_similarity = -100.00 # Big negative number
    final_word = None 
    input_words_set = set([word_a, word_b, word_c])
    for word in words:
        # If same words are found
        if word in input_words_set : 
            continue
            
        # Otherwise, compute the cosine similarity
        sim = cosine_similarity((e_b-e_a), (word_2_vec_map[word]-e_c))
        
        if sim > max_cosine_similarity : 
            max_cosine_sim = sim
            final_word = word
        
    return final_word

# %%
words
# Out:
# {'भ्यालुसहित',
#  'अमोवी',
#  'रुममेटहरूसँग',
#  'नाउं',
#  'जीवनमरण',
#  'माओवादीवीच',
#  'त्यसमाने',
#  'जीवात्हरू',
#  'आउँदाखेरी',
#  'उड्यनन',
#  'हुनुन्छ',
#  'पांखा',
#  'घटनाबीच',
#  'चिक्र',
#  'भोलिपल्ट',
#  'दैलेखस्थित',
#  'प्रत्याशितपूर्ण',
#  'युज्भेन्द्र',
#  'रिमेम्बरेन्स',
#  'धर्मस',
#  'पिकअफ',
#  'नफर्कन',
#  'लाहुरे',
#  'बाँडेर',
#  'होल्गर',
#  'सिरियापछि',
#  'खटाईए',
#  'भ्रुण',
#  'एनएएमयु',
#  'उत्सुकतता',
#  'निर्धक्',
#  'फाल्दिएछन्',
#  'लुमिनार्क',
#  'गर्र्\u200dयौं',
#  'मेकअपसम्बन्धी',
#  'ड्ेरफस',
#  'प्रतिस्प्रधी',
#  'माघकृष्ण',
#  'धादिङवेसीतर्फ',
#  'मितव्यीता',
#  'खगा',
#  'शोषणकारी',
#  'चिताउनुपरे',
#  'समात्दो',
#  'ग्रान्डसँग',
#  'बाँझेच्यानडाँडाअल्छेढुंगा',
#  'पिठावालासित',
#  'इन्टरसेक्स',
#  'टलपल',
#  'गणेश',
#  'फर्काइदिन',
#  'नकिना',
#  'त्योचित्त',
#  'एब्सोल्युट',
#  'पारदर्शितासाथ',
#  'जहाँछन्',
#  'ओलीमात्र',
#  'हृदयकेन्द्र',
#  'प्रमिता',
#  'ओर्लिनेबित्ति',
#  'भेगतिर',
#  'बाँसगजेरी',
#  'भरि',
#  'रुविन्दु',
#  'अन्त्यमामुलुक',
#  'विदेशिनुभन्दा',
#  'घोरासैने',
#  'जेबीचन्द',
#  'अरूजत्ति',
#  'जान्नुहोस',
#  'सुविधाहरूबारे',
#  'अफरजस्ता',
#  'ठुलाहरू',
#  'ल्यापटपम्याकबुक',
#  'म्याग्नेटिक',
#  'लेते',
#  'बिक्रमासिङ्घे',
#  'सुकाउना',
#  'काथीरेसान',
#  'पूर्वअनुमानभन्दा',
#  'पूर्तिके',
#  'पुगेछन',
#  'मुम्बइ',
#  'जनकवि',
#  'पिरोलिए',
#  'उचाईं',
#  'निष्कर्षबारे',
#  'मझुवामाइ',
#  'कफीचोक',
#  'हुनुपर्दैनथ्यो',
#  'रोगमुक्त',
#  'आत्तिइ',
#  'लागतार',
#  'नेटृमसल्फ',
#  'कोषबाटै',
#  'सेम्राङडाँडा',
#  'ह्यारी',
#  'त्यसैकाल',
#  'डिटेल्स',
#  'आधुनिककालसम्म',
#  'न्युन्तम',
#  'भ्रष्टाचारीमाथि',
#  'हार्\u200dयौँ',
#  'गोठओडार',
#  'निस्तब्धता',
#  'डि्रम्स',
#  'हाइड्रोरोथेरापी',
#  'आहूत',
#  'फाँड्नु',
#  'गर्दैे',
#  'मोराट',
#  'भाण्टा',
#  'लोफ्भेन',
#  'डाकपिलदेव',
#  'यात्रुहरूमाझ',
#  'स्तनसँग',
#  'ट्राइब्रेकर',
#  'छिमेकीमुलुक',
#  'परासीतर्फ',
#  'रोशी',
#  'बेलाठु',
#  'पक्डिउन्',
#  'घरखेतसम्म',
#  'इन्टिलीजेन्स',
#  'हम्बोल्ट',
#  'प्रेय',
#  'सुपरपावर',
#  'अन्तनिर्हित',
#  'बिस्तारबादी',
#  'पिरेम',
#  'उफान',
#  'स्टाइलडिजाइन',
#  'टपरीहरू',
#  'छेर्ने',
#  'छाउपडीप्रति',
#  'बालाबाखर',
#  'प्रतापी',
#  'राइढुंगी',
#  'बौद्धिष्ट',
#  'सडकसीमा',
#  'सुमिरकुमार',
#  'दिइरहेका',
#  'डामहेश्वर',
#  'मच्चाउनेछ',
#  'लाबुसकाग्न',
#  'परम्परा‚',
#  'न्यारोगेज',
#  'सिटीइभिटी',
#  'नजानिंदो',
#  'ट्युवरक्लोसिस',
#  'कम्पोजिसनसँग',
#  'विश्वविद्यालयबिच',
#  'वषै',
#  'काउण्टर',
#  'सतसट्ठी',
#  'पद्च्युत',
#  'डाइरेक्टरी',
#  'रिपलेन्टलगायत',
#  'भन्सारशुल्क',
#  'दुर्व्यासनी',
#  'सुदुरपश्चि',
#  'स्टेसनभित्र',
#  'गरेरकाम',
#  'अस्सरा',
#  'सोहले',
#  'ओभर',
#  'राजपत्राङ्कति',
#  'चिम्लिइदिँदा',
#  'मानवाधिकारविरुद्ध',
#  'लुज्नु',
#  'राबत',
#  'सबैछन्',
#  'वारेन्टबिना',
#  'पुनश्चरण',
#  'ठग्गा',
#  'पच्चा',
#  'पीएमेल',
#  'श्यामन',
#  'नाैलाे',
#  'अन्नडा',
#  'सन्जयकुमार',
#  'स्त्रीलम्पट',
#  'थालीः',
#  'सहमतितुल्य',
#  'बोइङसम्म',
#  'विवाह',
#  'मेरिनो',
#  'रिर्पाेट',
#  'भिएलएनवाट',
#  'घटनासम्बन्धी',
#  'ट्रयाकटु',
#  'कम्प्यूटरस',
#  'फ्रावि',
#  'हेपि',
#  'राईसम्म',
#  'शलाह',
#  'मूत्रसम्बन्धी',
#  'रोसालेडा',
#  'आेंठे',
#  'स्वीसक्याम्प',
#  'एडेन',
#  'पत्रपत्रिकालाईमात्र',
#  'गोलावारी',
#  'आरसिरिज',
#  'रकमझिक्न',
#  'मणिकर्ण',
#  'गोरुहाट',
#  'झत्ता',
#  'संघियताप्रति',
#  'थारुदङ्गौरा',
#  '\u200bसिमरा',
#  'मगरबीच',
#  'मुगुबासी',
#  'प्रतिरोपनीसम्म',
#  'अधिकारीहरूबी',
#  'रओछ्यान',
#  'जेनतेन',
#  'श्रखलासँग',
#  'समन्वयविना',
#  'फिनिगे',
#  'उपसभपाति',
#  'हुसानीसंग',
#  'खुद्राखुद्री',
#  'इन्फ्रारेड',
#  'भुकताङ्',
#  'कोलुन',
#  'निद्र्वन्द्वी',
#  'गङ्दी',
#  'राजपाक्ष',
#  'लोभरेनविरुद्ध',
#  'सचिवकाे',
#  'स्काउटराष्ट्रिय',
#  'पन्छीभैं',
#  'देखाउनुहुन्न',
#  'थेग्रे',
#  'सिएह',
#  'पम्पीसेट',
#  'मानाकोट',
#  'सर्वधारणा',
#  'राजदुतमाथि',
#  'साँघुरोमात्रै',
#  'फुटबलबाटै',
#  'टिप्नुपूर्व',
#  'सतुंगलतिर',
#  'पुरुषोचित',
#  'अकाउन्टहरु',
#  'युट्युबसम्म',
#  'दामिर',
#  'सहयोगगर्ने',
#  'व्यापारयुद्ध',
#  'इन्टेलिजेन्स',
#  'राजधानीपछि',
#  'दूधपान',
#  'लक्ष्मीकृपा',
#  'बीआईसीसी',
#  'संस्थासँग',
#  'पत्नीशोक',
#  'बाबादिन',
#  'मारिनर्स',
#  'चुरोटजस्ता',
#  'सुतेजस्तै',
#  'सुनाउंँथे',
#  'माइतभन्दा',
#  'बाडफाँट',
#  'योगहल',
#  'घुटो',
#  'पूर्ववर्तीहरु',
#  'असीवटा',
#  'वढ्नु',
#  'रोडाढुंगा',
#  'वार्मअफ',
#  'गोरुसिंगो',
#  'बुढागाउँलगायत',
#  'एंफिबियस',
#  'व्यवधानविरोध',
#  'बच्चुु',
#  'रेनवे',
#  'अनुष्',
#  'निरअंसी',
#  'रसिङ',
#  'गणितः',
#  'ग्याभिङ्ग',
#  'यापर',
#  'बेरोजगारअर्धबेरोजगार',
#  'प्रमुखमुख्यमन्त्री',
#  'सेरीगाँउ',
#  'पेय',
#  'एग्रोभेटहरू',
#  'सश\u200cंकित',
#  'स्थानान्तरणजस्ता',
#  'असूल्दा',
#  'आलोकविरुद्ध',
#  'उरुग्वेबीच',
#  'छुङ्लिउ',
#  'दोम्फे',
#  'जर्मनीमाथि',
#  'मेरोवरिपरि',
#  'तिरङ्गा',
#  'फट्याकफुटुक',
#  'खासगरि',
#  'अंँगालेर',
#  'सशा',
#  'सतर्कताअपनाउन',
#  'क्रनाल',
#  'अक्सिटोसन',
#  'सेतिङ',
#  'हरिवंशप्रति',
#  'पढिसक्दा',
#  'झिल्टुङ',
#  'हीथर',
#  'काविर',
#  'प्रतिकठठा',
#  'सिमेन्टा',
#  'टीकार्थी',
#  'श्रष्टाहरूबारे',
#  'असन्चो',
#  'सलुट्रो',
#  'बुच्चो',
#  'मांशपेशि',
#  '\u200bथ्रेसहोल्ड',
#  'भन्ठान्',
#  'प्रोटेक्सन',
#  'घाइतेहरु',
#  'सास्थी',
#  'पुग्द',
#  'नीरादेवी',
#  'साबधिक',
#  'महत्त्वकाङ्क्षा',
#  'सिंहापुर',
#  'छमकला',
#  'फेदीसम्म',
#  'व्यक्तित्वभन्दा',
#  'टर्कीलगयत',
#  'आदेशानुसार',
#  'काड्ने',
#  'साँदनी',
#  'प्रष्ट्याउछ',
#  'स्वण',
#  'बससेवा',
#  'शिद्धिविक्रम',
#  'गोमांतक',
#  'घटक',
#  'सामाजिकभाषिक',
#  'फोटोकिसानहरु',
#  'मैरिमो',
#  'किशोरीतर्फ',
#  '\u200bक्युबा',
#  'सिरोहियालगायत',
#  'हिवप',
#  'कानुनबेगर',
#  'परमामी',
#  'मुइलेनबर्ग',
#  'मठमन्दिरभित्र',
#  'मनोहरासाँखु',
#  'माटै',
#  'प्रयोजना',
#  'हुुनुभ',
#  'टक्र्याउँछु',
#  'मेयरकहाँ',
#  'लठ्ठालगायत',
#  'यानगोनस्थित',
#  'अन्तरलिंगी',
#  'सतसिङ',
#  'बासेवास',
#  'गर्दैछौं',
#  'बडाललगायत',
#  'ड्या',
#  'थ्रीस्टारजस्ता',
#  'जगद्\u200dगुरु',
#  'बारक',
#  'केमोमिला',
#  'विभत्सता',
#  'प्रामाणिकास्',
#  'व्यवस्थापनलाई',
#  'डिल्लीसिंह',
#  'टाप्टिङ',
#  'फ्यासन',
#  'शष',
#  'साधारणतय',
#  'फ्रेन्चइज',
#  'मुखयमन्त्री',
#  'अन्नपात',
#  'छ्डोने',
#  'हुनपुग्छे',
#  'प्रतिकँल',
#  'अश्रृग्यास',
#  'हूने',
#  'राप्रापा',
#  'गौशालाएयरपोर्ट',
#  'पन्छाइ',
#  'छेक्ने',
#  'रामदयाल',
#  'ईभीएम',
#  'फुपुसहित',
#  'यसपटककोकुवेतसम्म',
#  'शीर्षस्थानमा',
#  'पराउन्न',
#  'मोल्डेन',
#  'तिरीरहे',
#  'प्रमुखहरूसंँग',
#  'साततल्ले',
#  'मसान्त',
#  'चौथाइसम्म',
#  'नङगशल',
#  'रिडीरुद्रवेणीपालुङखोला',
#  'प्रतिप्याराग्लाइडिङ',
#  'पोखुँ',
#  'भाषाप्रेमीसित',
#  'स्वचालित',
#  'एकाउण्ट',
#  'मर्मतगरी',
#  'टुनिसियासँग',
#  'अलंकेरा',
#  'तपचुली',
#  'लगानीकैै',
#  'समाधानक',
#  'गरिदिनुभए',
#  'चङ्खे',
#  'पर्यटकलेबढी',
#  'लप्पन',
#  'वैङ्क',
#  'नगुमाइकन',
#  'मर्जप्रक्रिया',
#  'चिह्नसम्बन्धी',
#  'ठडिइरहे',
#  'उपनपा',
#  'खारानेटासम्म',
#  'अशान्तिमाथि',
#  'खर्चअनुसार',
#  'भिजाइए',
#  'डकुमेण्ट्री',
#  'न्यायन्याय',
#  'इम्रिक',
#  'पदार्थमात्रै',
#  'परिपूर्ण',
#  'भोकोनाङ्गो',
#  'जिमुहा',
#  'मुलुकहरू',
#  'डेस्टानी',
#  'सिदारात',
#  'अस्पष्टसँग',
#  'सोझ्याउनैपर्\u200dयो',
#  'आँकलनलगायत',
#  'समानतामूूलक',
#  'भिख',
#  'कण्ठलगायत',
#  'लुट्पाट',
#  'दिअज',
#  'बाटोबारे',
#  'सत्याग्रहीप्रति',
#  'एब्सोलुट',
#  'कामदारहरूसँंग',
#  'मोवाइलबाटै',
#  'सामग्रीजस्ता',
#  'गोलप्रतिद्वन्द्वी',
#  'नेहरूभन्दा',
#  'जेठाजुजेठी',
#  'झल्काउँछ',
#  'क्यामेराभित्र',
#  'अन्तजस्तै',
#  'मधेसप्रदेश',
#  'ईन्डिया',
#  'प्रधान्यायाधीशविरुद्ध',
#  'संसदभित्रै',
#  'दयाभावबारे',
#  'हिउँचितुवा',
#  'करोडबारे',
#  'भास्कराचार्य',
#  'गर्नुपर्छपर्',
#  'भिट्टामोर',
#  'आफूह',
#  '\u200bविवादकाबीच',
#  'चौतारीसंगै',
#  'विसङ्ति',
#  'एड्ली',
#  'टोलाउँछन्',
#  'घिडघिडाउँ',
#  'कस्मेटिकलगायत',
#  'हांसजस्ता',
#  'मगाइयो',
#  'इनरुडेक',
#  'पदवीहरू',
#  'दिपेन्द',
#  'एएफएफ',
#  'थुनेलो',
#  'पुनर्निर्माणसम्बन्धी',
#  'कर्नरतिर',
#  'ओह्लिन',
#  'मच्याउन',
#  'बुद्द',
#  'पुर्वखेलाडी',
#  'हितोपदेश',
#  'तथाबर्दियासम्म',
#  'क्रायोइलेक्ट्रोन',
#  'बटोनेट',
#  'क्रिमिनलो',
#  'नेतृत्वस्तर',
#  'नारायणमानहरू',
#  'म्याडोनाडो',
#  'यथास्थितिवाद',
#  'कार्यक्रममाढंग',
#  'सञ्चारगृहलेसोच्थ्यो',
#  'टुवोर्ग',
#  'अफरलगत्तै',
#  'सवित्री',
#  'खिच्छौं',
#  'इरेक्टाइल',
#  'चािह',
#  'उर्गिन',
#  'जुटाईदिनु',
#  'पुख्य',
#  'बगाग',
#  'बजार्नुपरेथ्यो',
#  'अतितप्रति',
#  'त्यसैअनुकूल',
#  'भनेसफल',
#  'प्याफलतिर',
#  'सबबेस',
#  'बहकिने',
#  'नयॉ',
#  'अल्पसंख्य',
#  'सिक्ससम्म',
#  'भैरहवारुपन्देही',
#  'चुचुमारे',
#  'गुगलरहरू',
#  'खसिया',
#  'गौवा',
#  'ज्योती',
#  'लेखेपनिनलेखेपनि',
#  'घुम्नुहोस्',
#  'हावानली',
#  'अर्खले',
#  'पास्पोर्ट',
#  'घँचेडिरहे',
#  'अलिमलिए',
#  'लड्थे',
#  'अनुल्लङ्घनीय',
#  'निर्भरजस्तै',
#  'कभिन',
#  'सर्मि',
#  'सौरम',
#  'झप्की',
#  'बीउसम्म',
#  'यज्ञचक्रप्रति',
#  'पदर्थ',
#  'त्रिपुरासुरी',
#  'आवरणमात्र',
#  'चुलिंदो',
#  'जेठाबुढा',
#  'सर्जरीजस्ता',
#  'रङगमञ्च',
#  'आख्लेपाखा',
#  'अह्राइएकाखटाइए',
#  'हेन्लीस्थित',
#  'समातिएकाहरू',
#  'हेरिन्न',
#  'छेडदै',
#  'रङअविर',
#  'फुरुगं',
#  'चन्द्रज्योती',
#  'डीभीपीआर',
#  'सिभ',
#  'छिटेर',
#  'उपाध्ययविरुद्ध',
#  'दिनुसू',
#  'सुनाइरहे',
#  'सुबेडा',
#  'अधेरी',
#  'गाबी',
#  'घुँडामार',
#  'मोदीइमरान',
#  'प्याब्सक',
#  'माओवादीकालीन',
#  'चिह्नबिना',
#  'पुर्मती',
#  'रेमिटान्स',
#  'प्रतिवद्धताः',
#  'बिनास्क्रिप्ट',
#  'सुनबास',
#  'युवायुति',
#  'सागरकुण्डगोसाइँकुण्ड',
#  'आफन्तबिच',
#  'निस्कनुहुन्छ',
#  'उत्पदनशील',
#  'मट्टुर',
#  '\u200bदक्षिण',
#  'रिसाउँदा',
#  'सिनोटिक',
#  'सिंहद्वय',
#  'घोटिन्छ',
#  'कबिरा',
#  'जाक्सा',
#  'बाहै्रमास',
#  'जननायकहरू',
#  'कन्दी',
#  'ड्रिउ',
#  'बाइकसँग',
#  'फेसबूकलगायत',
#  'नधेकिलिने',
#  'राइफलबारे',
#  'गैरप्रतिस्पर्धी',
#  'अणुअस्त्र',
#  'अरमान्ड',
#  'उम्मेद्\u200dवार',
#  'सेवादिइरहे',
#  'जिन्क',
#  'गुह्श्वरी',
#  'वर्णव्यवस्था',
#  'अंगोला',
#  'बिचित्र',
#  'म्यानअफ',
#  'जर्\u200dयाकजुरुक्क',
#  'भन्नेस्थान',
#  'टाउकेलाइ',
#  'विमत',
#  'अर्नहवास्थित',
#  'मन्जुरीना',
#  'प्रणालीप्रति',
#  'पथ्र्यों',
#  'हुदापनि',
#  'बेलासम्म',
#  'उनीप्रति',
#  'नजन्मँ',
#  'अनिलकुमार',
#  'छिर्थ्यो',
#  'उबरै',
#  'पढ्थेंँ',
#  'पुनेश',
#  'साँध',
#  'ताप्लेजुंग',
#  'ढिकेनुन',
#  'चिनिसकि',
#  'अन्ड',
#  'देखिन्छन',
#  'चरिहे',
#  'रोक्\u200dने',
#  'बस्नेछैनौं',
#  'हरीमाया',
#  'फलामगरी',
#  'कलवार',
#  'बेलायतीसरह',
#  'श्रब्यदृष्य',
#  'पलाएछ',
#  'खड्काथो',
#  'लाठैलाठा',
#  'जीवनहरण',
#  'स्तुतिशास्त्र',
#  'ऋसिदेव',
#  'कामआफ्नो',
#  'प्रतिसेमेस्टर',
#  'वीरगञ्जकलैया',
#  'आतंकवादलार्इ',
#  'पित्तृसत्ताबाटै',
#  'वल्डइन',
#  'चुक्दैनौं',
#  'पाकिस्तानलक्षित',
#  'स्त्रिलिङ्गी',
#  'थुँतेर',
#  'बुझाइरहे',
#  'सुधारसुचना',
#  'उन्मादित',
#  'सेन्टक',
#  'अवस्थितिबारे',
#  'भर्छिन्',
#  'उपहानगर',
#  'पर्ख÷मंगलम',
#  'विरज',
#  'नदिऔं',
#  'नेकलाइन',
#  'जर्नेलहफ्तार',
#  'सन्तसाधु',
#  'बिजनेससम्बन्धी',
#  'अङ्कति',
#  'बौद्धमतावलम्बीहरू',
#  'हेम्जा',
#  'वाबजुद',
#  'प्रदेशमुकाम',
#  'ब्याकहु',
#  'थपेकोे',
#  'बिग्रेरलगायत',
#  'किरणविक्रम',
#  'असर्राफ',
#  'लिटेनिङ',
#  'वंशै',
#  'मिलनमात्र',
#  'डिकवेला',
#  'भाडिने',
#  'साथीभाइहरू',
#  'रीमाभिडियो',
#  'न्युड्स',
#  'ट्रान्समिसनलाइन',
#  'लेख्नुपरे',
#  'नभई',
#  'हुंगाखोला',
#  'एफडब्लूसीएस',
#  'एसडीएफप्रति',
#  'ल्याइरहन्थ्यो',
#  'च्यानलसम्म',
#  'आँखिर',
#  'हप्',
#  'होईनौं',
#  'चीत',
#  'उब्जाइदिएकोछ',
#  'कोटीसँग',
#  'सुःखम',
#  'जजमेन्टसँग',
#  'मुस्कुराउन',
#  'प्रतिपक्षीसम्म',
#  'डडेलधुरालगायत',
#  'सँसद',
#  'हजारपन्ध्र',
#  'स्वय\u200cंसेवक',
#  'श्रृङ्खलाभित्र',
#  'इजरायबीच',
#  'केन्स',
#  'ढप्प',
#  'सुहाउँदैनथ्यो',
#  'पोषणजन्य',
#  'मास्यौँ',
#  'गोल्डेनगेटसँग',
#  'वौद्धिकवर्ग',
#  'मगमगाउने',
#  'डोनरहरू',
#  'लेख्नेपढ्नेबोल्ने',
#  'कालागाढजोरागाउँ',
#  'नगरउपप्रमुख',
#  'नास्डक',
#  'शाल्म',
#  'विवादास्थल',
#  'चाँफा',
#  'भुवाँ',
#  'रोजगारउन्मुख',
#  'मानिसलेआफ्ना',
#  'एकखा',
#  'मदान',
#  'दमाईखोला',
#  'अाश्विन',
#  'खिली',
#  'श्याम्सुङ',
#  'स्टाप',
#  'आम्रपालि',
#  'स्वतन्त्रस्वायत्त',
#  'दिशानिर्देशन',
#  'रूकु',
#  'कतैवाट',
#  'प्रक्षिक्षक',
#  'अक्षरविम्ब',
#  'आङदावा',
#  'फिक्स्ड',
#  'हिंडिरहँदा',
#  'पुजिबाद',
#  'डोकट',
#  'लानुपर्\u200dयो',
#  'मूलद्वारसँगै',
#  'आयोजनाबट',
#  'कानुनीराज्य',
#  'अन्वेषण',
#  'गर्नुपर्थेन',
#  'ब्याकस्ट्रिट',
#  'ह्वास्सै',
#  'वार्ली',
#  'हर्डसफिल्डमाथि',
#  'तकसेरालगायत',
#  'काँकडभिट्टाफूलबारीबंगलाबन्द',
#  'ओशोधारा',
#  'प्लेइङसेट',
#  'ज्यूधन',
#  'जतिखेर',
#  'सम्सबीच',
#  'बेइज्जति',
#  'गर्मी',
#  'कोर्सअनुसार',
#  'राष्ट्रनेसन',
#  'वृद्धिजस्तै',
#  'द्वन्दवकालीन',
#  'दिलदास',
#  'घुमें',
#  'क्यारमबोर्ड',
#  'ग्लोबली',
#  'घर्तिदोभानसम्म',
#  'बुझाउनेमध्ये',
#  'नारायणलगायत',
#  'नोकसानी',
#  'टासीलामा',
#  'मिलपत्र',
#  'छाङदी',
#  'लागियदि',
#  'भूरा',
#  'बराब',
#  'फुटीमात्र',
#  'पिसीबी',
#  'संस्थासमेत',
#  'गोदौलिया',
#  'खस्क्यो',
#  'फ्ल्याटभित्र',
#  'कदमसम्बन्धी',
#  'प्रत्याभास',
#  'प्रवाह',
#  'डाइजा',
#  'निस्सिम',
#  'गराइपाउन',
#  'प्रत्यन',
#  'छुन्न',
#  'यौवनवय',
#  'सम्झौताबीच',
#  'फुडमान्डु',
#  'तमो',
#  'सक्दीन',
#  'अार्इडल',
#  'बसिसकेकाहरू',
#  'जैइब',
#  'सारभित्र',
#  'इन्सिन्या',
#  'मूलकाहरूमाथि',
#  'सामसङसहित',
#  'सहोदर',
#  'कालिखोला',
#  'सप्को',
#  'इन्जायम',
#  'सुदेव',
#  'वेलहाराडाँडास्थित',
#  'डम्मरसिंह',
#  'अलिक्काभन्दा',
#  'लेखकहरूसित',
#  'रेकर्डिङ्ग',
#  'बरपिपल',
#  'मन्त्रीत्रय',
#  'बन्दगरिए',
#  'स्काइट्राक्स',
#  'पशुपतिप्रसाद',
#  'भेदभावबारे',
#  'पत्नीसँग',
#  'कानुनभित्र',
#  'बिर्साउनेगरी',
#  'शिस्न',
#  'एक्कर्ड',
#  'भिताडी',
#  'मुकदर्शकजस्तै',
#  'बिछ्याइ',
#  'निस्केछन्',
#  'मनमन्दिर',
#  'गार्डसम्म',
#  'सोमर',
#  'नाचलगत्तै',
#  'म्यागनाभेमम',
#  'टिमटि',
#  'सुवर्णप्रभादेवी',
#  'लिज्ड',
#  'क्\u200dयान्भासझैँ',
#  'मेनिक्योर',
#  'एसएबी',
#  'मृगस्थलीस्थित',
#  'डब्लुएफडिवाई',
#  'नखोल्',
#  'पुत्रवत्',
#  'मुद्दाचलाउने',
#  'मुठो',
#  'विश्वासिलाहरू',
#  'वर्कट',
#  'हालम्म',
#  'राष्ट्रवावादी',
#  'नाङ्गो',
#  'दिँइरहँदा',
#  'रत्नलालकाे',
#  'देवापार',
#  'प्लेसर',
#  'खोजिए',
#  'भेस्वाकर',
#  'कुविन',
#  'वाख्वाई',
#  'तिर्थाटनबारे',
#  'लाइहाल्छन्',
#  'आत्तुरी',
#  'आलेसहित',
#  'भाँचिबस्थे',
#  'कार्यान्वयनदर',
#  'दारेसलाम',
#  'क्ल्याप',
#  'हुनेबित्तिक्',
#  'डाअर्जुन',
#  'पोखाउँदा',
#  'आसपाससम्म',
#  'दालमे',
#  'शरिरभित्र',
#  'हस्मतुल्लाह',
#  'उद्धारकार्य',
#  'कारितास',
#  'भक्तज',
#  'डण्डीमात्रै',
#  'मनै',
#  'त्रिवेणीघाट',
#  'खोपासीत्रिशूली',
#  'शाशन',
#  'खाोप',
#  'डेडिकेशन',
#  'ल्याउँदैनथ्यो',
#  'नपुुग्ने',
#  'माइजोगमाई',
#  'बिटल्स्',
#  'केहिवर्ष',
#  'हदबन्दीसम्बन्धी',
#  'गर्मीजस्ता',
#  'मौवाटारलगायत',
#  'खुलाउनै',
#  'नदेखाईकन',
#  'विकेटमात्र',
#  'सुनद्धारी',
#  'काेमैला',
#  'मदिरामुक्त',
#  'अनुुसरण',
#  'निजीतर्फ',
#  'त्याग्ने',
#  'पानअमेरिकन',
#  'खेतनजि',
#  'अद्यागमनअधिकारी',
#  'जीवनस्तरभन्दा',
#  'घारघोडेपानीवीरेठाँटी',
#  'आरुघाटतर्फ',
#  'गहतलगायत',
#  'चो',
#  'हुकुमसिंह',
#  'शृंगारयुक्त',
#  'जिताए',
#  'बजेटिङ',
#  'गुठीसंस्थान',
#  'बन्द—हडताल',
#  'लुडविङ',
#  'सिर्जनबाबु',
#  'फुमिहि',
#  'निजहरुउपर',
#  'आरटिएन',
#  'ग्राह्स्थ',
#  'फालेझौ',
#  'चिलोसिस',
#  'परस्थानीय',
#  'थुुलुङ्ग',
#  'हजुरबुबाआमा',
#  'जापानः',
#  'उडिरहने',
#  'फल्लोअप',
#  'सङग्रह',
#  'बासहरू',
#  'नकाटिदि',
#  'कानुनमन्त्रीभन्दा',
#  'ब्लगबस्टर',
#  'सुईं',
#  'बोलाइदिन्छु',
#  'दुक्तान',
#  '—दिव्यराज',
#  'जिस्वन',
#  'लिम्बुबीच',
#  'भारैभार',
#  'चिप्लिन',
#  'चमिरा',
#  'सुरुपरासी',
#  'दर्शी',
#  'एकेडेमीसाग',
#  'प्रवेशिकासरह',
#  'उठी',
#  'व्याबसायिक',
#  'युएईंविरुद्ध',
#  'रेकी',
#  'बल्खुचोभार',
#  'नसर्न',
#  'अफम्यानेजमेन्ट',
#  'वाइलट',
#  'व्यवसायबिना',
#  'जम्बुल्हा',
#  'आचार्यवीरगन्ज',
#  'सामूहिकश्रवण',
#  'वर्देवा',
#  'संस्थाईपान',
#  'सडकसीमाभित्र',
#  'नदेलान',
#  'साइकोलोजिस्ट',
#  'मेडिटेसनरिल्याक्सेसन',
#  'सुटुपो',
#  'दर्शर्क',
#  'ठिके',
#  'तर्जृ',
#  'ब्रहामण्ड',
#  'डिएन',
#  'युरोनोमस',
#  'भनिरहिए',
#  'बड्तौला',
#  'सोधीबस्छ',
#  'तदअनुकूल',
#  'मुक्केबा',
#  'पुग्यौँ',
#  'गजाखस्टा',
#  'कुङमिन',
#  'मानोक्रस',
#  'समाधिस्थ',
#  'पुयार्\u200dएर',
#  'उसकासे',
#  'हैकमवादी',
#  'घटाउनेसम्बन्ध',
#  'कवाज',
#  'अस्पतालप्रमुख',
#  'पर्यटकस्तर',
#  ...}
